# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV
import numpy as np
import matrix_dev
import matplotlib.pyplot as plt
import _pickle
import gensim
import gensim.corpora as corpora
import os
from pprint import pprint
from gensim.models import CoherenceModel
from nltk.corpus import stopwords
import spacy
import pandas as pd
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt 
# %matplotlib inline
from lda_implementation import lda_model

# %%
lda = lda_model()
lda.load_data('raw_docs', 'dev')
# Out:
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /home/vcheruiy/.local/lib/python3.5/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# loading pickles
# /home/vcheruiy/.local/lib/python3.5/site-packages/gensim/models/phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
path = os.path.join("../../feature_groups/lda_pickles", 'best_model')
with open(path, "rb") as f:
    best_model = _pickle.load(f)
# Out:
# <gensim.models.wrappers.ldamallet.LdaMallet object at 0x7f5e2388fe80>
