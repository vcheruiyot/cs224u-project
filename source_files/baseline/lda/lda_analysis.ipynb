# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV
import numpy as np
import matrix_dev
import matplotlib.pyplot as plt
import _pickle
import gensim
import gensim.corpora as corpora
import os
from pprint import pprint
from gensim.models import CoherenceModel
from nltk.corpus import stopwords
import spacy
import pandas as pd
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt 
# %matplotlib inline
from lda_implementation import lda_model
import csv

# %%
lda = lda_model()
lda.load_data('raw_docs', 'dev')
# Out:
# /Users/nantanick/anaconda/envs/nlu/lib/python3.6/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# /Users/nantanick/anaconda/envs/nlu/lib/python3.6/site-packages/msgpack_numpy.py:88: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr))[0]
# /Users/nantanick/anaconda/envs/nlu/lib/python3.6/site-packages/msgpack_numpy.py:84: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   dtype=np.dtype(descr)).reshape(obj[b'shape'])
# ...

# %%
model = lda.lda_mallet_model()
# Out:
# Coherence Score:  0.6006093247957731

# %%
dominant_topic = lda.domininant_topic(model)

# %%
dominant_topic
# Out:
#       Dominant_Topic  Perc_Contribution  \
# 0               29.0             0.0266
# 1               41.0             0.0291
# 2               65.0             0.0223
# 3                1.0             0.0291
# 4               36.0             0.0276
# 5               42.0             0.0227
# 6               46.0             0.0198
# 7               38.0             0.0234
# 8               42.0             0.0276
# 9               52.0             0.0223
# 10              12.0             0.0282
# 11              22.0             0.0298
# 12              67.0             0.0177
# 13              45.0             0.0257
# 14              39.0             0.0379
# 15              43.0             0.0312
# 16              16.0             0.0346
# 17              35.0             0.0251
# 18               1.0             0.0180
# 19               0.0             0.0143
# 20               0.0             0.0286
# 21              28.0             0.0411
# ...

# %%
lda2 = lda_model()
lda2.load_data('raw_docs', 'dev')

# %%
dom2 = lda2.domininant_topic(model)

# %%
dom2

# %%
name = 'model_test'
path = os.path.join('../../feature_groups/lda_pickles', name)
with open(path, "wb") as f:
	model.save(f)
