# %%
#load packages
import os
import sys
module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from preprocessing.preprocess import PreProcessText

# %%
#Our input tweet
tweet = 'Hey!'

# %%
#preprocess the tweet
preprocessor = PreProcessText()
prep_tweet = preprocessor.formatTweet(tweet)

# %%
prep_tweet
# Out:
# 'hey'

# %%
rec = recommender()

# %%
rec.recommender(prep_tweet)
