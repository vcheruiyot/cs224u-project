# %%
import numpy as np
import matrix_dev
import _pickle
import gensim
import gensim.corpora as corpora
import os
from pprint import pprint
from gensim.models import CoherenceModel
from nltk.corpus import stopwords
import spacy
import pandas as pd
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from lda_implementation import lda_model
import sys
sys.path.insert(0, '../../')
from preprocessing.preprocess import PreProcessText

# %%
tweet = "I love America!"

# %%
prep = PreProcessText()
tweet_formatted = prep.formatTweet(tweet)

# %%
tweet_formatted
# Out:
# 'i love america'

# %%
bow = corpus.dictionary.doc2bow(tweet_formatted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-54ffdf09887e> in <module>()
# ----> 1 bow = corpus.dictionary.doc2bow(tweet_formatted)
#
# NameError: name 'corpus' is not defined
