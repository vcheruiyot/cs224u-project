# %%
import numpy as np
import matrix_dev
import _pickle
import gensim
import gensim.corpora as corpora
import os
from pprint import pprint
from gensim.models import CoherenceModel
from nltk.corpus import stopwords
import spacy
import pandas as pd
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from lda_implementation import lda_model
import sys
sys.path.insert(0, '../../')
from preprocessing.preprocess import PreProcessText

# %%
lda = lda_model()
lda.load_data('raw_docs', 'dev')
# Out:
# loading pickles
# /Users/nantanick/anaconda/envs/nlu/lib/python3.6/site-packages/gensim/models/phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
path = os.path.join("../../feature_groups/lda_pickles", 'best_model')
with open(path, "rb") as f:
    best_model = _pickle.load(f)

# %%
tweet = "thinking about making a serious stand for your future and your income for 2010"

# %%
prep = PreProcessText()
tweet_formatted = prep.formatTweet(tweet).split(' ')

# %%
tweet_formatted
# Out:
# ['thinking',
#  'about',
#  'making',
#  'a',
#  'serious',
#  'stand',
#  'for',
#  'your',
#  'future',
#  'and',
#  'your',
#  'income',
#  'for',
#  '2010']

# %%
bow = lda.id2word.doc2bow(tweet_formatted)

# %%
topics = best_model[bow]

# %%
best_topic = max(topics, key= lambda x: x[1])

# %%
best_topic
# Out:
# (328, 0.009974747474747567)

# %%
topics
# Out:
# [(0, 0.0020032051282051514),
#  (1, 0.0020032051282051514),
#  (2, 0.0020032051282051514),
#  (3, 0.0020032051282051514),
#  (4, 0.0020032051282051514),
#  (5, 0.0020032051282051514),
#  (6, 0.0020032051282051514),
#  (7, 0.0020032051282051514),
#  (8, 0.0020032051282051514),
#  (9, 0.0020032051282051514),
#  (10, 0.0020032051282051514),
#  (11, 0.0020032051282051514),
#  (12, 0.0020032051282051514),
#  (13, 0.0020032051282051514),
#  (14, 0.0020032051282051514),
#  (15, 0.0020032051282051514),
#  (16, 0.0020032051282051514),
#  (17, 0.0020032051282051514),
#  (18, 0.0020032051282051514),
#  (19, 0.0020032051282051514),
#  (20, 0.0020032051282051514),
#  (21, 0.0020032051282051514),
#  (22, 0.0020032051282051514),
#  (23, 0.0020032051282051514),
#  (24, 0.0020032051282051514),
#  (25, 0.0020032051282051514),
#  (26, 0.0020032051282051514),
#  (27, 0.0020032051282051514),
#  (28, 0.0020032051282051514),
#  (29, 0.0020032051282051514),
#  (30, 0.0020032051282051514),
# ...
