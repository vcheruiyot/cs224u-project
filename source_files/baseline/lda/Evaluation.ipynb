# %%
import numpy as np
import matrix_dev
import matplotlib.pyplot as plt
import _pickle
import gensim
import gensim.corpora as corpora
import os
from pprint import pprint
from gensim.models import CoherenceModel
from gensim.corpora import MalletCorpus
from nltk.corpus import stopwords
import spacy
import pandas as pd
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from evaluation import evaluator

# %%
evaluate = evaluator()

# %%
evaluate.load_test_y('supertest.json')

# %%
evaluate.load_test_x('supertest_clean')

# %%
model = evaluate.load_model_pickle(name = 'best_model')
model = evaluate.load_bigrams(name = 'bigram')
# Out:
# loading model: best_model
# loading bigram: bigram

# %%
evaluate.calculate_recall()
# Out:
# 0 {'para', 'mai', 'pra', 'por', 'la'}
# 1 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 2 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 3 {'giveaway', 'win', 'follow', 'end', 'free'}
# 4 {'android', 'http', 'bit', 'fb', 'twitter'}
# 5 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 6 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 7 {'game', 'http', 'today', 'worldcup', 'usa'}
# 8 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 9 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 10 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 11 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 12 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 13 {'meet', 'rt', 'die', 'election', '_'}
# 14 {'bottle', 'food', 'red', 'wine', 'drink'}
# 15 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 16 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 17 {'android', 'http', 'bit', 'fb', 'twitter'}
# 18 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 19 {'android', 'http', 'bit', 'fb', 'twitter'}
# 20 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 21 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 22 {'call', 'stop', 'wiunion', 'state', 'give'}
# 23 {'giveaway', 'win', 'follow', 'end', 'free'}
# 24 {'meet', 'rt', 'die', 'election', '_'}
# 25 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 26 {'love', 'god', 'man', 'give', 'life'}
# 27 {'call', 'stop', 'wiunion', 'state', 'give'}
# 28 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 29 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 30 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 31 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 32 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 33 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 34 {'call', 'stop', 'wiunion', 'state', 'give'}
# 35 {'meet', 'rt', 'die', 'election', '_'}
# 36 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 37 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 38 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 39 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 40 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 41 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 42 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 43 {'back', 'day', 'work', 'happy', 'today'}
# 44 {'love', 'god', 'man', 'give', 'life'}
# 45 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 46 {'love', 'god', 'man', 'give', 'life'}
# 47 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 48 {'android', 'http', 'bit', 'fb', 'twitter'}
# 49 {'game', 'http', 'today', 'worldcup', 'usa'}
# 50 {'bottle', 'food', 'red', 'wine', 'drink'}
# 51 {'para', 'mai', 'pra', 'por', 'la'}
# 52 {'live', 'video', 'http', 'haiti', 'bit'}
# 53 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 54 {'meet', 'rt', 'die', 'election', '_'}
# 55 {'back', 'day', 'work', 'happy', 'today'}
# 56 {'cont', 'office', 'http', 'bit', 'photo'}
# 57 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 58 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 59 {'giveaway', 'win', 'follow', 'end', 'free'}
# 60 {'love', 'god', 'man', 'give', 'life'}
# 61 {'para', 'mai', 'pra', 'por', 'la'}
# 62 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 63 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 64 {'android', 'http', 'bit', 'fb', 'twitter'}
# 65 {'back', 'day', 'work', 'happy', 'today'}
# 66 {'giveaway', 'win', 'follow', 'end', 'free'}
# 67 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 68 {'para', 'mai', 'pra', 'por', 'la'}
# 69 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 70 {'game', 'http', 'today', 'worldcup', 'usa'}
# 71 {'call', 'stop', 'wiunion', 'state', 'give'}
# 72 {'para', 'mai', 'pra', 'por', 'la'}
# 73 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 74 {'para', 'mai', 'pra', 'por', 'la'}
# 75 {'game', 'http', 'today', 'worldcup', 'usa'}
# 76 {'game', 'http', 'today', 'worldcup', 'usa'}
# 77 {'giveaway', 'win', 'follow', 'end', 'free'}
# 78 {'back', 'day', 'work', 'happy', 'today'}
# 79 {'game', 'http', 'today', 'worldcup', 'usa'}
# 80 {'news', 'www', 'http', 'america', 'job'}
# 81 {'back', 'day', 'work', 'happy', 'today'}
# 82 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 83 {'call', 'stop', 'wiunion', 'state', 'give'}
# 84 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 85 {'bottle', 'food', 'red', 'wine', 'drink'}
# 86 {'live', 'video', 'http', 'haiti', 'bit'}
# 87 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 88 {'bottle', 'food', 'red', 'wine', 'drink'}
# 89 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 90 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 91 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 92 {'para', 'mai', 'pra', 'por', 'la'}
# 93 {'live', 'video', 'http', 'haiti', 'bit'}
# 94 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 95 {'giveaway', 'win', 'follow', 'end', 'free'}
# 96 {'love', 'god', 'man', 'give', 'life'}
# 97 {'para', 'mai', 'pra', 'por', 'la'}
# 98 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 99 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 100 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 101 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 102 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 103 {'bottle', 'food', 'red', 'wine', 'drink'}
# 104 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 105 {'bottle', 'food', 'red', 'wine', 'drink'}
# 106 {'android', 'http', 'bit', 'fb', 'twitter'}
# 107 {'love', 'god', 'man', 'give', 'life'}
# 108 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 109 {'android', 'http', 'bit', 'fb', 'twitter'}
# 110 {'giveaway', 'win', 'follow', 'end', 'free'}
# 111 {'game', 'http', 'today', 'worldcup', 'usa'}
# 112 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 113 {'news', 'www', 'http', 'america', 'job'}
# 114 {'make', 'people', 'great', 'time', 'good'}
# 115 {'love', 'god', 'man', 'give', 'life'}
# 116 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 117 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 118 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 119 {'love', 'god', 'man', 'give', 'life'}
# 120 {'bottle', 'food', 'red', 'wine', 'drink'}
# 121 {'make', 'people', 'great', 'time', 'good'}
# 122 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 123 {'live', 'video', 'http', 'haiti', 'bit'}
# 124 {'call', 'stop', 'wiunion', 'state', 'give'}
# 125 {'love', 'god', 'man', 'give', 'life'}
# 126 {'meet', 'rt', 'die', 'election', '_'}
# 127 {'love', 'god', 'man', 'give', 'life'}
# 128 {'para', 'mai', 'pra', 'por', 'la'}
# 129 {'call', 'stop', 'wiunion', 'state', 'give'}
# 130 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 131 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 132 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 133 {'live', 'video', 'http', 'haiti', 'bit'}
# 134 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 135 {'para', 'mai', 'pra', 'por', 'la'}
# 136 {'para', 'mai', 'pra', 'por', 'la'}
# 137 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 138 {'para', 'mai', 'pra', 'por', 'la'}
# 139 {'android', 'http', 'bit', 'fb', 'twitter'}
# 140 {'android', 'http', 'bit', 'fb', 'twitter'}
# 141 {'love', 'god', 'man', 'give', 'life'}
# 142 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 143 {'para', 'mai', 'pra', 'por', 'la'}
# 144 {'make', 'people', 'great', 'time', 'good'}
# 145 {'make', 'people', 'great', 'time', 'good'}
# 146 {'para', 'mai', 'pra', 'por', 'la'}
# 147 {'make', 'people', 'great', 'time', 'good'}
# 148 {'news', 'www', 'http', 'america', 'job'}
# 149 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 150 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 151 {'para', 'mai', 'pra', 'por', 'la'}
# 152 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 153 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 154 {'game', 'http', 'today', 'worldcup', 'usa'}
# 155 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 156 {'meet', 'rt', 'die', 'election', '_'}
# 157 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 158 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 159 {'live', 'video', 'http', 'haiti', 'bit'}
# 160 {'giveaway', 'win', 'follow', 'end', 'free'}
# 161 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 162 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 163 {'giveaway', 'win', 'follow', 'end', 'free'}
# 164 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 165 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 166 {'para', 'mai', 'pra', 'por', 'la'}
# 167 {'love', 'god', 'man', 'give', 'life'}
# 168 {'back', 'day', 'work', 'happy', 'today'}
# 169 {'news', 'www', 'http', 'america', 'job'}
# 170 {'game', 'http', 'today', 'worldcup', 'usa'}
# 171 {'para', 'mai', 'pra', 'por', 'la'}
# 172 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 173 {'make', 'people', 'great', 'time', 'good'}
# 174 {'game', 'http', 'today', 'worldcup', 'usa'}
# 175 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 176 {'meet', 'rt', 'die', 'election', '_'}
# 177 {'call', 'stop', 'wiunion', 'state', 'give'}
# 178 {'bottle', 'food', 'red', 'wine', 'drink'}
# 179 {'android', 'http', 'bit', 'fb', 'twitter'}
# 180 {'game', 'http', 'today', 'worldcup', 'usa'}
# 181 {'live', 'video', 'http', 'haiti', 'bit'}
# 182 {'para', 'mai', 'pra', 'por', 'la'}
# 183 {'live', 'video', 'http', 'haiti', 'bit'}
# 184 {'bottle', 'food', 'red', 'wine', 'drink'}
# 185 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 186 {'android', 'http', 'bit', 'fb', 'twitter'}
# 187 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 188 {'make', 'people', 'great', 'time', 'good'}
# 189 {'para', 'mai', 'pra', 'por', 'la'}
# 190 {'love', 'god', 'man', 'give', 'life'}
# 191 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 192 {'giveaway', 'win', 'follow', 'end', 'free'}
# 193 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 194 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 195 {'love', 'god', 'man', 'give', 'life'}
# 196 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 197 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 198 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 199 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 200 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 201 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 202 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 203 {'back', 'day', 'work', 'happy', 'today'}
# 204 {'make', 'people', 'great', 'time', 'good'}
# 205 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 206 {'back', 'day', 'work', 'happy', 'today'}
# 207 {'love', 'god', 'man', 'give', 'life'}
# 208 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 209 {'para', 'mai', 'pra', 'por', 'la'}
# 210 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 211 {'para', 'mai', 'pra', 'por', 'la'}
# 212 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 213 {'live', 'video', 'http', 'haiti', 'bit'}
# 214 {'meet', 'rt', 'die', 'election', '_'}
# 215 {'bottle', 'food', 'red', 'wine', 'drink'}
# 216 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 217 {'love', 'god', 'man', 'give', 'life'}
# 218 {'meet', 'rt', 'die', 'election', '_'}
# 219 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 220 {'bottle', 'food', 'red', 'wine', 'drink'}
# 221 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 222 {'back', 'day', 'work', 'happy', 'today'}
# 223 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 224 {'back', 'day', 'work', 'happy', 'today'}
# 225 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 226 {'meet', 'rt', 'die', 'election', '_'}
# 227 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 228 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 229 {'back', 'day', 'work', 'happy', 'today'}
# 230 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 231 {'back', 'day', 'work', 'happy', 'today'}
# 232 {'call', 'stop', 'wiunion', 'state', 'give'}
# 233 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 234 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 235 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 236 {'live', 'video', 'http', 'haiti', 'bit'}
# 237 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 238 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 239 {'call', 'stop', 'wiunion', 'state', 'give'}
# 240 {'love', 'god', 'man', 'give', 'life'}
# 241 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 242 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 243 {'android', 'http', 'bit', 'fb', 'twitter'}
# 244 {'love', 'god', 'man', 'give', 'life'}
# 245 {'bottle', 'food', 'red', 'wine', 'drink'}
# 246 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 247 {'bottle', 'food', 'red', 'wine', 'drink'}
# 248 {'bottle', 'food', 'red', 'wine', 'drink'}
# 249 {'game', 'http', 'today', 'worldcup', 'usa'}
# 250 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 251 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 252 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 253 {'make', 'people', 'great', 'time', 'good'}
# 254 {'back', 'day', 'work', 'happy', 'today'}
# 255 {'back', 'day', 'work', 'happy', 'today'}
# 256 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 257 {'back', 'day', 'work', 'happy', 'today'}
# 258 {'giveaway', 'win', 'follow', 'end', 'free'}
# 259 {'meet', 'rt', 'die', 'election', '_'}
# 260 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 261 {'love', 'god', 'man', 'give', 'life'}
# 262 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 263 {'back', 'day', 'work', 'happy', 'today'}
# 264 {'cont', 'office', 'http', 'bit', 'photo'}
# 265 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 266 {'love', 'god', 'man', 'give', 'life'}
# 267 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 268 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 269 {'love', 'god', 'man', 'give', 'life'}
# 270 {'bottle', 'food', 'red', 'wine', 'drink'}
# 271 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 272 {'meet', 'rt', 'die', 'election', '_'}
# 273 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 274 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 275 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 276 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 277 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 278 {'call', 'stop', 'wiunion', 'state', 'give'}
# 279 {'giveaway', 'win', 'follow', 'end', 'free'}
# 280 {'make', 'people', 'great', 'time', 'good'}
# 281 {'love', 'god', 'man', 'give', 'life'}
# 282 {'para', 'mai', 'pra', 'por', 'la'}
# 283 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 284 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 285 {'news', 'www', 'http', 'america', 'job'}
# 286 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 287 {'para', 'mai', 'pra', 'por', 'la'}
# 288 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 289 {'android', 'http', 'bit', 'fb', 'twitter'}
# 290 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 291 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 292 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 293 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 294 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 295 {'make', 'people', 'great', 'time', 'good'}
# 296 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 297 {'bottle', 'food', 'red', 'wine', 'drink'}
# 298 {'call', 'stop', 'wiunion', 'state', 'give'}
# 299 {'bottle', 'food', 'red', 'wine', 'drink'}
# 300 {'back', 'day', 'work', 'happy', 'today'}
# 301 {'make', 'people', 'great', 'time', 'good'}
# 302 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 303 {'news', 'www', 'http', 'america', 'job'}
# 304 {'call', 'stop', 'wiunion', 'state', 'give'}
# 305 {'game', 'http', 'today', 'worldcup', 'usa'}
# 306 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 307 {'meet', 'rt', 'die', 'election', '_'}
# 308 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 309 {'game', 'http', 'today', 'worldcup', 'usa'}
# 310 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 311 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 312 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 313 {'meet', 'rt', 'die', 'election', '_'}
# 314 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 315 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 316 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 317 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 318 {'call', 'stop', 'wiunion', 'state', 'give'}
# 319 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 320 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 321 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 322 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 323 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 324 {'giveaway', 'win', 'follow', 'end', 'free'}
# 325 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 326 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 327 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 328 {'meet', 'rt', 'die', 'election', '_'}
# 329 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 330 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 331 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 332 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 333 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 334 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 335 {'android', 'http', 'bit', 'fb', 'twitter'}
# 336 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 337 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 338 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 339 {'para', 'mai', 'pra', 'por', 'la'}
# 340 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 341 {'back', 'day', 'work', 'happy', 'today'}
# 342 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 343 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 344 {'bottle', 'food', 'red', 'wine', 'drink'}
# 345 {'bottle', 'food', 'red', 'wine', 'drink'}
# 346 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 347 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 348 {'bottle', 'food', 'red', 'wine', 'drink'}
# 349 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 350 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 351 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 352 {'bottle', 'food', 'red', 'wine', 'drink'}
# 353 {'android', 'http', 'bit', 'fb', 'twitter'}
# 354 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 355 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 356 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 357 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 358 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 359 {'back', 'day', 'work', 'happy', 'today'}
# 360 {'call', 'stop', 'wiunion', 'state', 'give'}
# 361 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 362 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 363 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 364 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 365 {'love', 'god', 'man', 'give', 'life'}
# 366 {'back', 'day', 'work', 'happy', 'today'}
# 367 {'android', 'http', 'bit', 'fb', 'twitter'}
# 368 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 369 {'android', 'http', 'bit', 'fb', 'twitter'}
# 370 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 371 {'meet', 'rt', 'die', 'election', '_'}
# 372 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 373 {'news', 'www', 'http', 'america', 'job'}
# 374 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 375 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 376 {'para', 'mai', 'pra', 'por', 'la'}
# 377 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 378 {'bottle', 'food', 'red', 'wine', 'drink'}
# 379 {'android', 'http', 'bit', 'fb', 'twitter'}
# 380 {'news', 'www', 'http', 'america', 'job'}
# 381 {'love', 'god', 'man', 'give', 'life'}
# 382 {'love', 'god', 'man', 'give', 'life'}
# 383 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 384 {'android', 'http', 'bit', 'fb', 'twitter'}
# 385 {'para', 'mai', 'pra', 'por', 'la'}
# 386 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 387 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 388 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 389 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 390 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 391 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 392 {'make', 'people', 'great', 'time', 'good'}
# 393 {'back', 'day', 'work', 'happy', 'today'}
# 394 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 395 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 396 {'love', 'god', 'man', 'give', 'life'}
# 397 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 398 {'make', 'people', 'great', 'time', 'good'}
# 399 {'para', 'mai', 'pra', 'por', 'la'}
# 400 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 401 {'news', 'www', 'http', 'america', 'job'}
# 402 {'call', 'stop', 'wiunion', 'state', 'give'}
# 403 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 404 {'para', 'mai', 'pra', 'por', 'la'}
# 405 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 406 {'para', 'mai', 'pra', 'por', 'la'}
# 407 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 408 {'call', 'stop', 'wiunion', 'state', 'give'}
# 409 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 410 {'call', 'stop', 'wiunion', 'state', 'give'}
# 411 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 412 {'giveaway', 'win', 'follow', 'end', 'free'}
# 413 {'make', 'people', 'great', 'time', 'good'}
# 414 {'news', 'www', 'http', 'america', 'job'}
# 415 {'para', 'mai', 'pra', 'por', 'la'}
# 416 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 417 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 418 {'meet', 'rt', 'die', 'election', '_'}
# 419 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 420 {'live', 'video', 'http', 'haiti', 'bit'}
# 421 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 422 {'back', 'day', 'work', 'happy', 'today'}
# 423 {'android', 'http', 'bit', 'fb', 'twitter'}
# 424 {'make', 'people', 'great', 'time', 'good'}
# 425 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 426 {'back', 'day', 'work', 'happy', 'today'}
# 427 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 428 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 429 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 430 {'bottle', 'food', 'red', 'wine', 'drink'}
# 431 {'live', 'video', 'http', 'haiti', 'bit'}
# 432 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 433 {'para', 'mai', 'pra', 'por', 'la'}
# 434 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 435 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 436 {'bottle', 'food', 'red', 'wine', 'drink'}
# 437 {'cont', 'office', 'http', 'bit', 'photo'}
# 438 {'android', 'http', 'bit', 'fb', 'twitter'}
# 439 {'game', 'http', 'today', 'worldcup', 'usa'}
# 440 {'bottle', 'food', 'red', 'wine', 'drink'}
# 441 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 442 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 443 {'back', 'day', 'work', 'happy', 'today'}
# 444 {'meet', 'rt', 'die', 'election', '_'}
# 445 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 446 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 447 {'para', 'mai', 'pra', 'por', 'la'}
# 448 {'para', 'mai', 'pra', 'por', 'la'}
# 449 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 450 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 451 {'back', 'day', 'work', 'happy', 'today'}
# 452 {'giveaway', 'win', 'follow', 'end', 'free'}
# 453 {'giveaway', 'win', 'follow', 'end', 'free'}
# 454 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 455 {'live', 'video', 'http', 'haiti', 'bit'}
# 456 {'back', 'day', 'work', 'happy', 'today'}
# 457 {'meet', 'rt', 'die', 'election', '_'}
# 458 {'love', 'god', 'man', 'give', 'life'}
# 459 {'live', 'video', 'http', 'haiti', 'bit'}
# 460 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 461 {'meet', 'rt', 'die', 'election', '_'}
# 462 {'android', 'http', 'bit', 'fb', 'twitter'}
# 463 {'game', 'http', 'today', 'worldcup', 'usa'}
# 464 {'para', 'mai', 'pra', 'por', 'la'}
# 465 {'make', 'people', 'great', 'time', 'good'}
# 466 {'news', 'www', 'http', 'america', 'job'}
# 467 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 468 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 469 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 470 {'back', 'day', 'work', 'happy', 'today'}
# 471 {'giveaway', 'win', 'follow', 'end', 'free'}
# 472 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 473 {'bottle', 'food', 'red', 'wine', 'drink'}
# 474 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 475 {'game', 'http', 'today', 'worldcup', 'usa'}
# 476 {'call', 'stop', 'wiunion', 'state', 'give'}
# 477 {'cont', 'office', 'http', 'bit', 'photo'}
# 478 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 479 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 480 {'bottle', 'food', 'red', 'wine', 'drink'}
# 481 {'giveaway', 'win', 'follow', 'end', 'free'}
# 482 {'news', 'www', 'http', 'america', 'job'}
# 483 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 484 {'back', 'day', 'work', 'happy', 'today'}
# 485 {'live', 'video', 'http', 'haiti', 'bit'}
# 486 {'meet', 'rt', 'die', 'election', '_'}
# 487 {'call', 'stop', 'wiunion', 'state', 'give'}
# 488 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 489 {'game', 'http', 'today', 'worldcup', 'usa'}
# 490 {'make', 'people', 'great', 'time', 'good'}
# 491 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 492 {'make', 'people', 'great', 'time', 'good'}
# 493 {'giveaway', 'win', 'follow', 'end', 'free'}
# 494 {'giveaway', 'win', 'follow', 'end', 'free'}
# 495 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 496 {'meet', 'rt', 'die', 'election', '_'}
# 497 {'live', 'video', 'http', 'haiti', 'bit'}
# 498 {'para', 'mai', 'pra', 'por', 'la'}
# 499 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 500 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 501 {'para', 'mai', 'pra', 'por', 'la'}
# 502 {'game', 'http', 'today', 'worldcup', 'usa'}
# 503 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 504 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 505 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 506 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 507 {'game', 'http', 'today', 'worldcup', 'usa'}
# 508 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 509 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 510 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 511 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 512 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 513 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 514 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 515 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 516 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 517 {'bottle', 'food', 'red', 'wine', 'drink'}
# 518 {'game', 'http', 'today', 'worldcup', 'usa'}
# 519 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 520 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 521 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 522 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 523 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 524 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 525 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 526 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 527 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 528 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 529 {'giveaway', 'win', 'follow', 'end', 'free'}
# 530 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 531 {'bottle', 'food', 'red', 'wine', 'drink'}
# 532 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 533 {'back', 'day', 'work', 'happy', 'today'}
# 534 {'back', 'day', 'work', 'happy', 'today'}
# 535 {'live', 'video', 'http', 'haiti', 'bit'}
# 536 {'giveaway', 'win', 'follow', 'end', 'free'}
# 537 {'giveaway', 'win', 'follow', 'end', 'free'}
# 538 {'bottle', 'food', 'red', 'wine', 'drink'}
# 539 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 540 {'love', 'god', 'man', 'give', 'life'}
# 541 {'giveaway', 'win', 'follow', 'end', 'free'}
# 542 {'meet', 'rt', 'die', 'election', '_'}
# 543 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 544 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 545 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 546 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 547 {'game', 'http', 'today', 'worldcup', 'usa'}
# 548 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 549 {'giveaway', 'win', 'follow', 'end', 'free'}
# 550 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 551 {'back', 'day', 'work', 'happy', 'today'}
# 552 {'meet', 'rt', 'die', 'election', '_'}
# 553 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 554 {'giveaway', 'win', 'follow', 'end', 'free'}
# 555 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 556 {'bottle', 'food', 'red', 'wine', 'drink'}
# 557 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 558 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 559 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 560 {'back', 'day', 'work', 'happy', 'today'}
# 561 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 562 {'make', 'people', 'great', 'time', 'good'}
# 563 {'love', 'god', 'man', 'give', 'life'}
# 564 {'back', 'day', 'work', 'happy', 'today'}
# 565 {'love', 'god', 'man', 'give', 'life'}
# 566 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 567 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 568 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 569 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 570 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 571 {'giveaway', 'win', 'follow', 'end', 'free'}
# 572 {'giveaway', 'win', 'follow', 'end', 'free'}
# 573 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 574 {'game', 'http', 'today', 'worldcup', 'usa'}
# 575 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 576 {'giveaway', 'win', 'follow', 'end', 'free'}
# 577 {'para', 'mai', 'pra', 'por', 'la'}
# 578 {'meet', 'rt', 'die', 'election', '_'}
# 579 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 580 {'bottle', 'food', 'red', 'wine', 'drink'}
# 581 {'para', 'mai', 'pra', 'por', 'la'}
# 582 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 583 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 584 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 585 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 586 {'meet', 'rt', 'die', 'election', '_'}
# 587 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 588 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 589 {'meet', 'rt', 'die', 'election', '_'}
# 590 {'bottle', 'food', 'red', 'wine', 'drink'}
# 591 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 592 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 593 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 594 {'back', 'day', 'work', 'happy', 'today'}
# 595 {'back', 'day', 'work', 'happy', 'today'}
# 596 {'android', 'http', 'bit', 'fb', 'twitter'}
# 597 {'love', 'god', 'man', 'give', 'life'}
# 598 {'para', 'mai', 'pra', 'por', 'la'}
# 599 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 600 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 601 {'para', 'mai', 'pra', 'por', 'la'}
# 602 {'live', 'video', 'http', 'haiti', 'bit'}
# 603 {'back', 'day', 'work', 'happy', 'today'}
# 604 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 605 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 606 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 607 {'giveaway', 'win', 'follow', 'end', 'free'}
# 608 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 609 {'para', 'mai', 'pra', 'por', 'la'}
# 610 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 611 {'meet', 'rt', 'die', 'election', '_'}
# 612 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 613 {'back', 'day', 'work', 'happy', 'today'}
# 614 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 615 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 616 {'back', 'day', 'work', 'happy', 'today'}
# 617 {'game', 'http', 'today', 'worldcup', 'usa'}
# 618 {'para', 'mai', 'pra', 'por', 'la'}
# 619 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 620 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 621 {'live', 'video', 'http', 'haiti', 'bit'}
# 622 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 623 {'para', 'mai', 'pra', 'por', 'la'}
# 624 {'love', 'god', 'man', 'give', 'life'}
# 625 {'meet', 'rt', 'die', 'election', '_'}
# 626 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 627 {'back', 'day', 'work', 'happy', 'today'}
# 628 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 629 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 630 {'call', 'stop', 'wiunion', 'state', 'give'}
# 631 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 632 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 633 {'para', 'mai', 'pra', 'por', 'la'}
# 634 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 635 {'call', 'stop', 'wiunion', 'state', 'give'}
# 636 {'back', 'day', 'work', 'happy', 'today'}
# 637 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 638 {'love', 'god', 'man', 'give', 'life'}
# 639 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 640 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 641 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 642 {'live', 'video', 'http', 'haiti', 'bit'}
# 643 {'android', 'http', 'bit', 'fb', 'twitter'}
# 644 {'giveaway', 'win', 'follow', 'end', 'free'}
# 645 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 646 {'love', 'god', 'man', 'give', 'life'}
# 647 {'love', 'god', 'man', 'give', 'life'}
# 648 {'giveaway', 'win', 'follow', 'end', 'free'}
# 649 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 650 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 651 {'giveaway', 'win', 'follow', 'end', 'free'}
# 652 {'love', 'god', 'man', 'give', 'life'}
# 653 {'news', 'www', 'http', 'america', 'job'}
# 654 {'love', 'god', 'man', 'give', 'life'}
# 655 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 656 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 657 {'game', 'http', 'today', 'worldcup', 'usa'}
# 658 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 659 {'giveaway', 'win', 'follow', 'end', 'free'}
# 660 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 661 {'bottle', 'food', 'red', 'wine', 'drink'}
# 662 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 663 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 664 {'make', 'people', 'great', 'time', 'good'}
# 665 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 666 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 667 {'call', 'stop', 'wiunion', 'state', 'give'}
# 668 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 669 {'android', 'http', 'bit', 'fb', 'twitter'}
# 670 {'call', 'stop', 'wiunion', 'state', 'give'}
# 671 {'bottle', 'food', 'red', 'wine', 'drink'}
# 672 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 673 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 674 {'bottle', 'food', 'red', 'wine', 'drink'}
# 675 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 676 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 677 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 678 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 679 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 680 {'android', 'http', 'bit', 'fb', 'twitter'}
# 681 {'love', 'god', 'man', 'give', 'life'}
# 682 {'live', 'video', 'http', 'haiti', 'bit'}
# 683 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 684 {'bottle', 'food', 'red', 'wine', 'drink'}
# 685 {'love', 'god', 'man', 'give', 'life'}
# 686 {'love', 'god', 'man', 'give', 'life'}
# 687 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 688 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 689 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 690 {'para', 'mai', 'pra', 'por', 'la'}
# 691 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 692 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 693 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 694 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 695 {'game', 'http', 'today', 'worldcup', 'usa'}
# 696 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 697 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 698 {'para', 'mai', 'pra', 'por', 'la'}
# 699 {'back', 'day', 'work', 'happy', 'today'}
# 700 {'love', 'god', 'man', 'give', 'life'}
# 701 {'make', 'people', 'great', 'time', 'good'}
# 702 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 703 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 704 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 705 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 706 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 707 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 708 {'back', 'day', 'work', 'happy', 'today'}
# 709 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 710 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 711 {'bottle', 'food', 'red', 'wine', 'drink'}
# 712 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 713 {'call', 'stop', 'wiunion', 'state', 'give'}
# 714 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 715 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 716 {'para', 'mai', 'pra', 'por', 'la'}
# 717 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 718 {'bottle', 'food', 'red', 'wine', 'drink'}
# 719 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 720 {'call', 'stop', 'wiunion', 'state', 'give'}
# 721 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 722 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 723 {'para', 'mai', 'pra', 'por', 'la'}
# 724 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 725 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 726 {'meet', 'rt', 'die', 'election', '_'}
# 727 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 728 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 729 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 730 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 731 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 732 {'bottle', 'food', 'red', 'wine', 'drink'}
# 733 {'meet', 'rt', 'die', 'election', '_'}
# 734 {'bottle', 'food', 'red', 'wine', 'drink'}
# 735 {'para', 'mai', 'pra', 'por', 'la'}
# 736 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 737 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 738 {'love', 'god', 'man', 'give', 'life'}
# 739 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 740 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 741 {'giveaway', 'win', 'follow', 'end', 'free'}
# 742 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 743 {'giveaway', 'win', 'follow', 'end', 'free'}
# 744 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 745 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 746 {'love', 'god', 'man', 'give', 'life'}
# 747 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 748 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 749 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 750 {'bottle', 'food', 'red', 'wine', 'drink'}
# 751 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 752 {'bottle', 'food', 'red', 'wine', 'drink'}
# 753 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 754 {'para', 'mai', 'pra', 'por', 'la'}
# 755 {'love', 'god', 'man', 'give', 'life'}
# 756 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 757 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 758 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 759 {'back', 'day', 'work', 'happy', 'today'}
# 760 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 761 {'game', 'http', 'today', 'worldcup', 'usa'}
# 762 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 763 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 764 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 765 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 766 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 767 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 768 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 769 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 770 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 771 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 772 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 773 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 774 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 775 {'news', 'www', 'http', 'america', 'job'}
# 776 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 777 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 778 {'bottle', 'food', 'red', 'wine', 'drink'}
# 779 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 780 {'giveaway', 'win', 'follow', 'end', 'free'}
# 781 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 782 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 783 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 784 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 785 {'live', 'video', 'http', 'haiti', 'bit'}
# 786 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 787 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 788 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 789 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 790 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 791 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 792 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 793 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 794 {'live', 'video', 'http', 'haiti', 'bit'}
# 795 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 796 {'giveaway', 'win', 'follow', 'end', 'free'}
# 797 {'love', 'god', 'man', 'give', 'life'}
# 798 {'android', 'http', 'bit', 'fb', 'twitter'}
# 799 {'love', 'god', 'man', 'give', 'life'}
# 800 {'live', 'video', 'http', 'haiti', 'bit'}
# 801 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 802 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 803 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 804 {'android', 'http', 'bit', 'fb', 'twitter'}
# 805 {'make', 'people', 'great', 'time', 'good'}
# 806 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 807 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 808 {'meet', 'rt', 'die', 'election', '_'}
# 809 {'love', 'god', 'man', 'give', 'life'}
# 810 {'call', 'stop', 'wiunion', 'state', 'give'}
# 811 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 812 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 813 {'make', 'people', 'great', 'time', 'good'}
# 814 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 815 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 816 {'bottle', 'food', 'red', 'wine', 'drink'}
# 817 {'meet', 'rt', 'die', 'election', '_'}
# 818 {'bottle', 'food', 'red', 'wine', 'drink'}
# 819 {'live', 'video', 'http', 'haiti', 'bit'}
# 820 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 821 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 822 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 823 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 824 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 825 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 826 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 827 {'para', 'mai', 'pra', 'por', 'la'}
# 828 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 829 {'bottle', 'food', 'red', 'wine', 'drink'}
# 830 {'giveaway', 'win', 'follow', 'end', 'free'}
# 831 {'bottle', 'food', 'red', 'wine', 'drink'}
# 832 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 833 {'bottle', 'food', 'red', 'wine', 'drink'}
# 834 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 835 {'meet', 'rt', 'die', 'election', '_'}
# 836 {'android', 'http', 'bit', 'fb', 'twitter'}
# 837 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 838 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 839 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 840 {'game', 'http', 'today', 'worldcup', 'usa'}
# 841 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 842 {'call', 'stop', 'wiunion', 'state', 'give'}
# 843 {'bottle', 'food', 'red', 'wine', 'drink'}
# 844 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 845 {'para', 'mai', 'pra', 'por', 'la'}
# 846 {'meet', 'rt', 'die', 'election', '_'}
# 847 {'back', 'day', 'work', 'happy', 'today'}
# 848 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 849 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 850 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 851 {'game', 'http', 'today', 'worldcup', 'usa'}
# 852 {'para', 'mai', 'pra', 'por', 'la'}
# 853 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 854 {'game', 'http', 'today', 'worldcup', 'usa'}
# 855 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 856 {'giveaway', 'win', 'follow', 'end', 'free'}
# 857 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 858 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 859 {'para', 'mai', 'pra', 'por', 'la'}
# 860 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 861 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 862 {'android', 'http', 'bit', 'fb', 'twitter'}
# 863 {'android', 'http', 'bit', 'fb', 'twitter'}
# 864 {'giveaway', 'win', 'follow', 'end', 'free'}
# 865 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 866 {'call', 'stop', 'wiunion', 'state', 'give'}
# 867 {'meet', 'rt', 'die', 'election', '_'}
# 868 {'android', 'http', 'bit', 'fb', 'twitter'}
# 869 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 870 {'call', 'stop', 'wiunion', 'state', 'give'}
# 871 {'meet', 'rt', 'die', 'election', '_'}
# 872 {'back', 'day', 'work', 'happy', 'today'}
# 873 {'make', 'people', 'great', 'time', 'good'}
# 874 {'call', 'stop', 'wiunion', 'state', 'give'}
# 875 {'love', 'god', 'man', 'give', 'life'}
# 876 {'meet', 'rt', 'die', 'election', '_'}
# 877 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 878 {'live', 'video', 'http', 'haiti', 'bit'}
# 879 {'love', 'god', 'man', 'give', 'life'}
# 880 {'call', 'stop', 'wiunion', 'state', 'give'}
# 881 {'cont', 'office', 'http', 'bit', 'photo'}
# 882 {'back', 'day', 'work', 'happy', 'today'}
# 883 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 884 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 885 {'android', 'http', 'bit', 'fb', 'twitter'}
# 886 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 887 {'para', 'mai', 'pra', 'por', 'la'}
# 888 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 889 {'giveaway', 'win', 'follow', 'end', 'free'}
# 890 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 891 {'giveaway', 'win', 'follow', 'end', 'free'}
# 892 {'live', 'video', 'http', 'haiti', 'bit'}
# 893 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 894 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 895 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 896 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 897 {'meet', 'rt', 'die', 'election', '_'}
# 898 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 899 {'make', 'people', 'great', 'time', 'good'}
# 900 {'bottle', 'food', 'red', 'wine', 'drink'}
# 901 {'giveaway', 'win', 'follow', 'end', 'free'}
# 902 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 903 {'back', 'day', 'work', 'happy', 'today'}
# 904 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 905 {'link', 'join', 'http', 'bit', 'ipod_ipad'}
# 906 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 907 {'love', 'god', 'man', 'give', 'life'}
# 908 {'cont', 'office', 'http', 'bit', 'photo'}
# 909 {'bottle', 'food', 'red', 'wine', 'drink'}
# 910 {'para', 'mai', 'pra', 'por', 'la'}
# 911 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 912 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 913 {'love', 'god', 'man', 'give', 'life'}
# 914 {'news', 'www', 'http', 'america', 'job'}
# 915 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 916 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 917 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 918 {'giveaway', 'win', 'follow', 'end', 'free'}
# 919 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 920 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 921 {'bottle', 'food', 'red', 'wine', 'drink'}
# 922 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 923 {'make', 'people', 'great', 'time', 'good'}
# 924 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 925 {'giveaway', 'win', 'follow', 'end', 'free'}
# 926 {'para', 'mai', 'pra', 'por', 'la'}
# 927 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 928 {'para', 'mai', 'pra', 'por', 'la'}
# 929 {'android', 'http', 'bit', 'fb', 'twitter'}
# 930 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 931 {'game', 'http', 'today', 'worldcup', 'usa'}
# 932 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 933 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 934 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 935 {'love', 'god', 'man', 'give', 'life'}
# 936 {'make', 'people', 'great', 'time', 'good'}
# 937 {'giveaway', 'win', 'follow', 'end', 'free'}
# 938 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 939 {'love', 'god', 'man', 'give', 'life'}
# 940 {'giveaway', 'win', 'follow', 'end', 'free'}
# 941 {'egypt', 'mubarak', 'jan', 'quot', 'freedom'}
# 942 {'live', 'video', 'http', 'haiti', 'bit'}
# 943 {'cont', 'office', 'http', 'bit', 'photo'}
# 944 {'back', 'day', 'work', 'happy', 'today'}
# 945 {'love', 'god', 'man', 'give', 'life'}
# 946 {'android', 'http', 'bit', 'fb', 'twitter'}
# 947 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 948 {'giveaway', 'win', 'follow', 'end', 'free'}
# 949 {'para', 'mai', 'pra', 'por', 'la'}
# 950 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 951 {'game', 'http', 'today', 'worldcup', 'usa'}
# 952 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 953 {'para', 'mai', 'pra', 'por', 'la'}
# 954 {'meet', 'rt', 'die', 'election', '_'}
# 955 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 956 {'bottle', 'food', 'red', 'wine', 'drink'}
# 957 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 958 {'news', 'www', 'http', 'america', 'job'}
# 959 {'live', 'video', 'http', 'haiti', 'bit'}
# 960 {'android', 'http', 'bit', 'fb', 'twitter'}
# 961 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 962 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 963 {'back', 'day', 'work', 'happy', 'today'}
# 964 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 965 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 966 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 967 {'para', 'mai', 'pra', 'por', 'la'}
# 968 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 969 {'love', 'god', 'man', 'give', 'life'}
# 970 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 971 {'teaparty', 'tcot', 'hcr', 'gop', 'obama'}
# 972 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 973 {'bottle', 'food', 'red', 'wine', 'drink'}
# 974 {'game', 'http', 'today', 'worldcup', 'usa'}
# 975 {'para', 'mai', 'pra', 'por', 'la'}
# 976 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 977 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 978 {'android', 'http', 'bit', 'fb', 'twitter'}
# 979 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 980 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 981 {'game', 'http', 'today', 'worldcup', 'usa'}
# 982 {'indonesia', 'aku', 'rt', 'mau', 'gue'}
# 983 {'dontjudgeme', 'lol', 'miss', 'feel', 'tweet'}
# 984 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 985 {'para', 'mai', 'pra', 'por', 'la'}
# 986 {'love', 'god', 'man', 'give', 'life'}
# 987 {'game', 'http', 'today', 'worldcup', 'usa'}
# 988 {'back', 'day', 'work', 'happy', 'today'}
# 989 {'bottle', 'food', 'red', 'wine', 'drink'}
# 990 {'release', 'http', 'julian_assange', 'wikileak', 'gd'}
# 991 {'meet', 'rt', 'die', 'election', '_'}
# 992 {'immigration', 'healthcare', 'http', 'bit', 'hcr'}
# 993 {'meet', 'rt', 'die', 'election', '_'}
# 994 {'back', 'day', 'work', 'happy', 'today'}
# 995 {'live', 'video', 'http', 'haiti', 'bit'}
# 996 {'hit', 'japan', 'tsunami', 'earthquake', 'http'}
# 997 {'would_like', 'show', 'watch', 'big', 'harrypotter'}
# 998 {'para', 'mai', 'pra', 'por', 'la'}
# 999 {'para', 'mai', 'pra', 'por', 'la'}
# 0.13399503722084366
